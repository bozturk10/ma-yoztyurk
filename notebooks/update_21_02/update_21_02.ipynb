# %% [markdown]
# ## 21.02.2024 - Update

# %% [markdown]
# ## Coding Scheme

# %% [markdown]
# - There was an already-generated coding scheme (by GESIS) for this survey question. **GLES Coding of the Most Important Political Problem (2018-2022):** https://search.gesis.org/research_data/ZA7957?doi=10.4232/1.14200
#     - Codes are  semi-automatically created with the help of a BERT model
#     - The question in Panel Waves 10-21 are classified and made available online.
#     - I downloaded the codes and the coded text data.

# %%
import os 
import pandas as pd
DATA_DIR= os.path.join('/dss/dsshome1/0F/ra46lup2/ma-yoztyurk/data')
code_df= pd.read_csv(os.path.join(DATA_DIR,r"GLES/coding_list2.csv"), sep=',')
code_df
# Out:
#     Code                                          Category  \
# 0    -99                                      keine Angabe
# 1    -98                                        weiß nicht
# 2      1                                         Sonstiges
# 3      2                   Wahlkampf und Regierungsbildung
# 4      3                Politische Strukturen und Prozesse
# 5      4  Werte, politische Kultur und Gesellschaftskritik
# 6      5                                        Demokratie
# 7      6                                            Medien
# 8      7                                        Bürokratie
# 9      8                                        Lobbyismus
# 10     9                                        Korruption
# 11    10                             Politikverdrossenheit
# 12    11                          Parteienkritik allgemein
# 13    12                         Parteienkritik spezifisch
# 14    13                   Politiker:innenkritik allgemein
# 15    14                  Politiker:innenkritik spezifisch
# 16    15                                        Populismus
# 17    16                                 Innere Sicherheit
# 18    17                           Kriminalität und Gewalt
# 19    18                                       Terrorismus
# 20    19                   Radikalisierung und Extremismus
# 21    20                                  Recht und Justiz
# 22    21                                      Außenpolitik
# 23    22                      Europa und Europäische Union
# 24    23             (Beziehungen Deutschlands zu den) USA
# 25    24            (Beziehungen Deutschlands zu) Russland
# 26    25             (Beziehungen Deutschlands zur) Türkei
# 27    26              Internationale Konflikte und Frieden
# 28    27                              Krieg in der Ukraine
# 29    28                                      Verteidigung
# 30    29                                     Sozialpolitik
# 31    30                             Soziale Gerechtigkeit
# 32    31                                             Armut
# 33    32                               Arbeitsmarktpolitik
# 34    33               Arbeitslosigkeit und Grundsicherung
# 35    34                                       Lohnpolitik
# 36    35                  Rente und Demographischer Wandel
# 37    36                         Migration und Integration
# 38    37                                Gesundheitspolitik
# 39    38                                            Pflege
# 40    39                                   Corona-Pandemie
# 41    40                                   Familienpolitik
# 42    41                                    Gleichstellung
# 43    42                                   Bildungspolitik
# 44    43                                      Schulpolitik
# 45    44                                    Energiepolitik
# 46    45                                     Umweltpolitik
# 47    46                                      Klimapolitik
# 48    47                                 Naturkatastrophen
# 49    48                                Wirtschaftspolitik
# 50    49                                       Preisniveau
# 51    50                                     Infrastruktur
# 52    51                            Digitale Infrastruktur
# 53    52                                   Verkehrspolitik
#
#                                              Examples  \
# 0   …, xxx, asdf, k.A., sag ich nicht, Elefantenbabys
# 1   weiß ich nicht, weiß nicht, keine Ahnung, kann...
# 2                                                   -
# 3   der nächste Bundeskanzler, Koalitionsverhandlu...
# 4   Regierungsform, Föderalismus, Kritik an Bundes...
# 5   Nationalismus, Rechtsruck, rechte Politik verm...
# 6   Demokratieerhaltung, mehr Bürgerbeteiligung, d...
# 7   Lügenpresse, GEZ, Rundfunkbeitrag, Pressefreiheit
# 8   Überbürokratisierung des gesamten Lebens, Beam...
# 9   Einfluss der Wirtschaft, Macht der Wirtschaft ...
# 10  Maskenaffäre, Lobbyismus und Korruption, Wirts...
# 11  Desinteresse der Bevölkerung, Politikmüde, Pol...
# 12  die Parteien kümmern sich nicht mehr um die no...
# 13  einfache Nennung einer Partei, Die SPD ist nic...
# 14  Politiker ignorieren das Volk, Unehrlichkeit d...
# 15             Merkel, Seehofer, Bundeskanzler Scholz
# 16  Populismus, Rechtspopulismus, Stimmungsmache, ...
# 17  Innenpolitik, zu wenig Polizei, mehr Sicherhei...
# 18  Kriminalitätsrate, zunehmende Gewalt, Kriminal...
# 19  NSU, RAF, Terror, Terrorismus, Terrorbekämpfun...
# 20  Extremismusbekämpfung, radikale Linke und Rech...
# 21  die abhanden gekommene Freiheit, Beckenbauer m...
# 22  die weltpolitische Lage, Rüstungsexporte und K...
# 23  Brexit, Europa zusammenhalten, gemeinsame euro...
# 24  Trump, Die Abhängigkeit von den USA, Amerikas ...
# 25  Konflikt mit Russland, wirtschaftliche Beziehu...
# 26  Ärger mit der Türkei, Erdogan und die Flüchtli...
# 27  Atomwaffen Iran/Nordkorea, Kriegsgefahr, Japan...
# 28  Ukraine, Ukraine-Krieg, Putinkrieg, Krimkrise,...
# 29  Aufrüstung, Wehrpflicht, Ausrüstung der Bundes...
# 30  ungerechte soziale Leistungen, wachsender Sozi...
# 31  die Ungleichheit, Chancengleichheit, Bevorzugu...
# 32  Dass Leute zur Tafel müssen, Menschen die hung...
# 33  Arbeit, Beschäftigungssituation, Überarbeitung...
# 34  Arbeitslosigkeit bzw. die Unlust vieler Jugend...
# 35  bessere Bezahlung der Arbeit, gerechtere Löhne...
# 36  auf Alte achten, Vorsorge für mein Alter, Lebe...
# 37  Grenzen dicht, zu viele Neubürger, Aussiedler,...
# 38  Kostenstruktur im Krankenhausbereich, Ärzteman...
# 39  Im Sozialsystem fehlen Pfleger. Zu geringe Löh...
# 40  Pandemie, Impfpflicht, Sofortige Wiederherstel...
# 41  Elterngeld, Kinderbetreuung, Erziehung, mehr E...
# 42  Feminismus, Ehe für alle, Adoptionen für Homos...
# 43  Bildung, Bafög, Bildungsföderalismus, in Bildu...
# 44  Lehrermangel, Ganztagsschulen, Pisa-Studie, Zu...
# 45  Ausbau/Finanzierung alternativer Energien, meh...
# 46  Massentierhaltung, Artenschutz, Abgase, Agrarw...
# 47  Klimaschutzziele, Co2-Emmissionen, Klimakatast...
# 48            Flutopfer im Ahrtal, Katastrophenschutz
# 49  Innovationskultur, Autoindustrie, die Wirtscha...
# 50  die hohen Preise, alles wird teurer, Kaufkraft...
# 51  Investitionen in die Infrastruktur, schlechte/...
# 52  Digitalisierung in deutschen Behörden, Breitba...
# 53  Verkehrswende, E-Mobilität, E-Autos, marode St...
#
#                                        Category_Eng  \
# 0                                    No information
# 1                                       Do not know
# 2                                             Other
# 3        Election campaign and government formation
# 4                Political structures and processes
# 5   Values, political culture, and social criticism
# 6                                         Democracy
# 7                                             Media
# 8                                       Bureaucracy
# 9                                          Lobbyism
# 10                                       Corruption
# 11                    Disillusionment with politics
# 12                     General criticism of parties
# 13                    Specific criticism of parties
# 14                 General criticism of politicians
# 15                Specific criticism of politicians
# 16                                         Populism
# 17                                Internal security
# 18                               Crime and violence
# 19                                        Terrorism
# 20                     Radicalization and extremism
# 21                                  Law and justice
# 22                                   Foreign policy
# 23                    Europe and the European Union
# 24                  Relations of Germany to the USA
# 25                   Relations of Germany to Russia
# 26                   Relations of Germany to Turkey
# 27                International conflicts and peace
# 28                                   War in Ukraine
# 29                                          Defense
# 30                                    Social policy
# 31                                   Social justice
# 32                                          Poverty
# 33                              Labor market policy
# 34                  Unemployment and basic security
# 35                                      Wage policy
# 36                   Pension and demographic change
# 37                        Migration and integration
# 38                                    Health policy
# 39                                             Care
# 40                                  Corona pandemic
# 41                                    Family policy
# 42                                         Equality
# 43                                 Education policy
# 44                                    School policy
# 45                                    Energy policy
# 46                             Environmental policy
# 47                                   Climate policy
# 48                                Natural disasters
# 49                                  Economic policy
# 50                                      Price level
# 51                                   Infrastructure
# 52                           Digital infrastructure
# 53                                 Transport policy
#
#                                           Example_Eng
# 0       ..., xxx, asdf, n/a, wont say, baby elephants
# 1        I don’t know, don’t know, no idea, can’t say
# 2                                                   -
# 3   the next Chancellor, coalition negotiations, e...
# 4   Form of government, federalism, criticism of f...
# 5   Nationalism, shift to the right, avoid right-w...
# 6   Preservation of democracy, more citizen partic...
# 7        Lying press, broadcasting fee, press freedom
# 8   Over-bureaucratization of entire life, abolish...
# 9   Influence of economy, power of economy in poli...
# 10  Mask scandal, lobbying and corruption, economy...
# 11  Population’s disinterest, weary of politics, d...
# 12  parties no longer care about ordinary citizens...
# 13  simple mention of a party, The SPD is no longe...
# 14  Politicians ignore the people, dishonesty of p...
# 15                Merkel, Seehofer, Chancellor Scholz
# 16  Populism, right-wing populism, stirring up emo...
# 17  Domestic policy, too few police, ensure more s...
# 18  Crime rate, increasing violence, crime by refu...
# 19  NSU, RAF, terror, terrorism, counter-terrorism...
# 20  Combating extremism, keeping radical left and ...
# 21  The lost freedom, Beckenbauer must go to jail,...
# 22  The global political situation, arms exports a...
# 23  Brexit, keeping Europe together, joint Europea...
# 24  Trump, The dependency on the USA, America’s im...
# 25  Conflict with Russia, expand economic relation...
# 26  Trouble with Turkey, Erdogan and the refugee r...
# 27  Nuclear weapons Iran/North Korea, risk of war,...
# 28  Ukraine, Ukraine war, Putin war, Crimea crisis...
# 29  Armament, conscription, equipment of the Bunde...
# 30  Unfair social benefits, growing welfare state ...
# 31  The inequality, equal opportunities, favoring ...
# 32  That people have to go to food banks, people w...
# 33  Work, employment situation, overhaul of our wo...
# 34  Unemployment or the unwillingness of many youn...
# 35  Better pay for work, fairer wages, social prof...
# 36  Care for the elderly, provision for my old age...
# 37  Close borders, too many new citizens, resettle...
# 38  Cost structure in the hospital sector, shortag...
# 39  Lack of caregivers in the social system. Too l...
# 40  Pandemic, vaccination mandate, immediate resto...
# 41  Parental allowance, childcare, education, more...
# 42  Feminism, marriage for all, adoptions for homo...
# 43  Education, Bafög, educational federalism, inve...
# 44  Shortage of teachers, all-day schools, Pisa st...
# 45  Expansion/financing of alternative energies, m...
# 46  Factory farming, species protection, emissions...
# 47  Climate protection goals, Co2 emissions, clima...
# 48  Flood victims in the Ahr valley, disaster prot...
# 49  Culture of innovation, automotive industry, th...
# 50  the high prices, everything is getting more ex...
# 51  Investments in infrastructure, poor/public inf...
# 52  Digitalization in German authorities, broadban...
# 53  Traffic turnaround, e-mobility, electric cars,...

# %% [markdown]
# ## Code percentages across panel waves

# %% [markdown]
# wave_class_perc.html

# %% [markdown]
# - Fine tuned **bert-base-german-cased** with 13000 (text_answer, answer_code) to code my synthetic answers.

# %% [markdown]
# ## Experiments with Llama-2-13b-chat-hf
#
# - setting up meta-llama/Llama-2-13b-chat-hf
# - experimenting with prompts.
# - results are in : https://docs.google.com/spreadsheets/d/1XyfMw1Z0waxiZDGzRkFmXDSOpK4iNtw_koA1rEVFixM/edit?usp=sharing

# %% [markdown]
# prompt used :

# %%
"""
<s>
[INST] 
    <<SYS>> 
        Identifizieren Sie im Jahr 2021 das wichtigste Problem, mit dem Deutschland aus der Sicht eines Befragten konfrontiert ist. 
        Geben Sie die Antwort in einem prägnanten Satz an, konzentrieren Sie sich nur auf ein einziges Thema ohne weitere Ausführungen oder Auflistung zusätzlicher Probleme. 
        Wiederholen Sie nicht die Informationen, die Ihnen gegeben wurden, und bitte geben Sie eine direkte Antwort ohne einleitende Phrasen. 
        Antworten Sie auf Deutsch.
    <</SYS>> 

    Der Befragte ist ein {age}-jähriger {gender}, der in {eastwest} Deutschland lebt und hauptsächlich {party} unterstützt. 
[/INST]
"""
# Out:
# '\n<s>\n[INST] \n    <<SYS>> \n        Identifizieren Sie im Jahr 2021 das wichtigste Problem, mit dem Deutschland aus der Sicht eines Befragten konfrontiert ist. \n        Geben Sie die Antwort in einem prägnanten Satz an, konzentrieren Sie sich nur auf ein einziges Thema ohne weitere Ausführungen oder Auflistung zusätzlicher Probleme. \n        Wiederholen Sie nicht die Informationen, die Ihnen gegeben wurden, und bitte geben Sie eine direkte Antwort ohne einleitende Phrasen. \n        Antworten Sie auf Deutsch.\n    <</SYS>> \n\n    Der Befragte ist ein {age}-jähriger {gender}, der in {eastwest} Deutschland lebt und hauptsächlich {party} unterstützt. \n[/INST]\n'

# %%
ex1_params = {"max_new_tokens": 300,
              "temperature":1,
              "do_sample":True}

ex2_params = {"max_new_tokens": 300,
              "temperature":1.5,
              "do_sample":True}

# %% [markdown]
# experiment result format:

# %%
log_sample= {
model_name:"meta-llama/Llama-2-13b-chat-hf"
survey_wave:21
user_id:10005
runtime:31.60722780227661
prompt:"<s>[INST] <<SYS>> Identifizieren Sie im Jahr 2021 das wichtigste Problem, mit dem Deutschland aus der Sicht eines Befragten konfrontiert ist. Geben Sie die Antwort in einem prägnanten Satz an, konzentrieren Sie sich nur auf ein einziges Thema ohne weitere Ausführungen oder Auflistung zusätzlicher Probleme. Wiederholen Sie nicht die Informationen, die Ihnen gegeben wurden, und bitte geben Sie eine direkte Antwort ohne einleitende Phrasen. Antworten Sie auf Deutsch. <</SYS>> Der Befragte ist ein 58-jähriger female, der in West Deutschland lebt und hauptsächlich GRÜNE unterstützt. [/INST] "
input_num_token:175
output_num_token:255
temperature:1.5
do_sample:true
max_new_tokens:300
output:"Laut Meinung des Befragten ist das wichtigste Problem, das Deutschland im Jahr 2021 konfrontiert, die anhaltende Demografie- und Altersstrukturwandel, da diese den Gesundheits- und Sozialsystemen stark belastet und eine Gefahrenquelle für dieirtschaftliche Stabilität des Landes darstellt."
}

# %% [markdown]
# - sampled 1000 rows from original survey.
# - removed dropped out & not answered respondents. (33)

# %% [markdown]
# - Temp and Answer Language

# %%
ex1_ex2= pd.read_csv(r"ex1_ex2.csv", sep=',')
print("temp 1 , answer languages")
print(ex1_ex2.output_ex1_lang.value_counts(1))
# Out:
# temp 1 , answer languages
# de    0.976215
# en    0.023785
# Name: output_ex1_lang, dtype: float64

# %%
print("temp==1.5 , answer languages")
print(ex1_ex2.output_ex2_lang.value_counts(1))
# Out:
# temp==1.5 , answer languages
# de    0.838676
# en    0.161324
# Name: output_ex2_lang, dtype: float64

# %% [markdown]
# - classified the experiment answers with german-bert model.
# - compared the frequencies : **sample_code_frequencies.html**

# %% [markdown]
# ## Todos & Questions
#
# - mixtral moe model : 1 GPU (16 GB) was not enought, I might try the model with 2 GPUs later.
# - does survey month matter ? should it be included in the prompt ?
# - should an experiment be repeated on the same sample to see variability ?
